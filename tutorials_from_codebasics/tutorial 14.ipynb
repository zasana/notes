# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("aapl.csv")
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0     7-Jul-17  142.90  144.75  142.90  144.18  19201712
# 1     6-Jul-17  143.02  143.50  142.41  142.73  24128782
# 2     5-Jul-17  143.69  144.79  142.72  144.09  21569557
# 3     3-Jul-17  144.88  145.30  143.10  143.50  14277848
# 4    30-Jun-17  144.45  144.96  143.78  144.02  23024107
# 5    29-Jun-17  144.71  145.13  142.28  143.68  31499368
# 6    28-Jun-17  144.49  146.11  143.16  145.83  22082432
# 7    27-Jun-17  145.01  146.16  143.62  143.73  24761891
# 8    26-Jun-17  147.17  148.28  145.38  145.82  25692361
# 9    23-Jun-17  145.13  147.16  145.11  146.28  35439389
# 10   22-Jun-17  145.77  146.70  145.12  145.63  19106294
# 11   21-Jun-17  145.52  146.07  144.61  145.87  21265751
# 12   20-Jun-17  146.87  146.87  144.94  145.01  24900073
# 13   19-Jun-17  143.66  146.74  143.66  146.34  32541404
# 14   16-Jun-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
type(df.Date[0])
# Out:
# str

# %%
# so we need to convert to a date format

# %%
df = pd.read_csv("aapl.csv", parse_dates=["Date"])
df
# Out:
#           Date    Open    High     Low   Close    Volume
# 0   2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1   2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2   2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3   2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4   2017-06-30  144.45  144.96  143.78  144.02  23024107
# 5   2017-06-29  144.71  145.13  142.28  143.68  31499368
# 6   2017-06-28  144.49  146.11  143.16  145.83  22082432
# 7   2017-06-27  145.01  146.16  143.62  143.73  24761891
# 8   2017-06-26  147.17  148.28  145.38  145.82  25692361
# 9   2017-06-23  145.13  147.16  145.11  146.28  35439389
# 10  2017-06-22  145.77  146.70  145.12  145.63  19106294
# 11  2017-06-21  145.52  146.07  144.61  145.87  21265751
# 12  2017-06-20  146.87  146.87  144.94  145.01  24900073
# 13  2017-06-19  143.66  146.74  143.66  146.34  32541404
# 14  2017-06-16  143.78  144.50  142.20  142.27  50361093
# ...

# %%
df = pd.read_csv("aapl.csv", parse_dates=["Date"],index_col=["Date"])
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-26  147.17  148.28  145.38  145.82  25692361
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# ...

# %%
# get partial date data
df["2017-07"]
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848

# %%
# get avg for that month
df["2017-01"].Close #get the closing price
df["2017-01"].Close.mean() #average stock price of apple in jan 2017
# Out:
# 119.57000000000001

# %%
df["2017-01-03"] #use the date as the specific index
# Out:
#              Open    High     Low   Close    Volume
# Date
# 2017-01-03  115.8  116.33  114.76  116.15  28781865

# %%
df["2017-01-07":"2017-01-01"] #take the range, order depends on the data order. this in case,
# [last date]:[first date] works as the later date is above
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-06  116.78  118.16  116.47  117.91  31751900
# 2017-01-05  115.92  116.86  115.81  116.61  22193587
# 2017-01-04  115.85  116.51  115.75  116.02  21118116
# 2017-01-03  115.80  116.33  114.76  116.15  28781865

# %%
#resampling

# %%
df.Close.resample("M").mean() #resample on monthly basis and get the mean of each month
# Out:
# Date
# 2016-07-31     99.473333
# 2016-08-31    107.665217
# 2016-09-30    110.857143
# 2016-10-31    115.707143
# 2016-11-30    110.154286
# 2016-12-31    114.335714
# 2017-01-31    119.570000
# 2017-02-28    133.713684
# 2017-03-31    140.617826
# 2017-04-30    142.886842
# 2017-05-31    152.227727
# 2017-06-30    147.831364
# 2017-07-31    143.625000
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
df.Close.resample("M").mean().plot()

# %%
# can shift tab to see documentations

# %%
df.Close.resample("Q").mean().plot()

# %%
df.Close.resample("Q").mean().plot(kind="bar")
